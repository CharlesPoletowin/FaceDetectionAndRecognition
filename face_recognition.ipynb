# %%
# !pip3 install face_recognition
# Out:
# ...
#      |████████████████████████████████| 100.2MB 67.3MB/s
# ...
#   Stored in directory: /root/.cache/pip/wheels/d2/99/18/59c6c8f01e39810415c0e63f5bede7d83dfb0ffc039865465f
# Successfully built face-recognition-models
# ...

# %% [markdown]
# 这是一个使用face_recognition 的python 库的example
#
#  <h5>上午1:29 </h5>
#   <h5>2019年6月11日（星期二）</h5>
#   <h5>Greenwich Mean Time (GMT) </h5>

# %% [markdown]
# 识别是否是同一个人

# %%
import face_recognition

picture_of_me = face_recognition.load_image_file("3a.jpg")
my_face_encoding = face_recognition.face_encodings(picture_of_me)[0]

# my_face_encoding now contains a universal 'encoding' of my facial features that can be compared to any other picture of a face!

unknown_picture = face_recognition.load_image_file("3b.jpg")
unknown_face_encoding = face_recognition.face_encodings(unknown_picture)[0]

# Now we can see the two face encodings are of the same person with `compare_faces`!

results = face_recognition.compare_faces([my_face_encoding], unknown_face_encoding)

if results[0] == True:
    print("It's a picture of two same people!")
else:
    print("It's not a picture of two same people!")
# Out:
# It's a picture of two same people!

# %%
# !git clone https://github.com/CharlesPoletowin/FaceDetectionAndRecognition
# !ls
# Out:
# Cloning into 'FaceDetectionAndRecognition'...
# remote: Enumerating objects: 34, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 34 (delta 1), reused 34 (delta 1), pack-reused 0
# Unpacking objects: 100% (34/34), done.
# 3a.jpg	3b.jpg	3c.jpg	FaceDetectionAndRecognition  sample_data

# %%
import os
os.chdir('FaceDetectionAndRecognition/testdata')

# %%
# !face_recognition ./known/ ./Unknown/
# Out:
# WARNING: More than one face found in ./known/abhishek-bachchan.jpg. Only considering the first face.
# ./Unknown/clive-owen4.jpg,CliveOwen
# ./Unknown/clive-owen3.jpg,CliveOwen
# ./Unknown/lattore_clive_owen_f4b4.jpg,CliveOwen
# ./Unknown/AbhishekBachan2.jpg,no_persons_found
# ./Unknown/clive-owen.jpg,CliveOwen
# ./Unknown/AbhishekBachan3.jpg,abhishek-bachchan
# ./Unknown/AbhishekBachan4.jpg,abhishek-bachchan
# ./Unknown/clive-owen-derailed.jpg,CliveOwen
# ./Unknown/clive-owen-derailed.jpg,unknown_person
# ./Unknown/AbhishekBachan1.jpg,unknown_person
# ./Unknown/AbhishekBachan1.jpg,abhishek-bachchan

# %%
# !face_detection ./known/
# Out:
# ./known/abhishek-bachchan.jpg,77,284,181,181
# ./known/CliveOwen.jpg,154,293,333,114

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg # mpimg 用于读取图片
# %matplotlib inline

# %%
os.chdir("known")
for i in os.listdir(r"./"):
  plt.imshow(mpimg.imread(i))
  plt.show()

# %%
os.chdir("../Unknown")
for i in os.listdir(r"./"):
  plt.imshow(mpimg.imread(i))
  plt.show()
os.chdir("..")
